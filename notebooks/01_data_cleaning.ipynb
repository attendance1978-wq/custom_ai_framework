# %% [markdown]
# # Data Cleaning Notebook
#
# This notebook handles data cleaning and preprocessing.

# %%
import json
from src.data.preprocess import preprocess_dialogues

# Run preprocessing
preprocess_dialogues('../data/raw/dialogues.jsonl', '../data/processed/train.jsonl')

print('Data cleaning completed')
